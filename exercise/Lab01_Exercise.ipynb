# %% [markdown]
# # Lab 01: Python Dictionary - Exercise
#
# ## Storing Disease Information for RAG Systems
#
# ---
#
# **Instructions:**
# 1. Complete all 5 exercises below
# 2. Replace `# YOUR CODE HERE` with your code
# 3. Run each cell to test your answer
# 4. When finished, push to GitHub for auto-grading
#
# **Total Points:** 100 (20 points each)
#
# **Time:** ~45 minutes
#
# ---

# %% [markdown]
# ## Exercise 1: Create a Dictionary (20 points)
#
# Create a dictionary called `dengue` with the following information:
#
# | Key | Value |
# |-----|-------|
# | name | Dengue Fever |
# | thai_name | ไข้เลือดออก |
# | symptoms | high fever, headache |
# | treatment | rest, fluids |

# %%
# Exercise 1: Create the dictionary
# YOUR CODE HERE

dengue = {
    # Add your key-value pairs here
}

# Test your answer (don't modify this part)
print(dengue)

# %%
# Verification cell for Exercise 1
assert dengue["name"] == "Dengue Fever", "name should be 'Dengue Fever'"
assert dengue["thai_name"] == "ไข้เลือดออก", "thai_name should be 'ไข้เลือดออก'"
assert dengue["symptoms"] == "high fever, headache", "symptoms should be 'high fever, headache'"
assert dengue["treatment"] == "rest, fluids", "treatment should be 'rest, fluids'"
print("✅ Exercise 1 Passed!")

# %% [markdown]
# ---
#
# ## Exercise 2: Add a New Key (20 points)
#
# Add a new key called `prevention` with value `mosquito repellent` to the `dengue` dictionary.

# %%
# Exercise 2: Add a new key to the dictionary
# YOUR CODE HERE



# Test your answer (don't modify this part)
print(dengue)

# %%
# Verification cell for Exercise 2
assert "prevention" in dengue, "Key 'prevention' not found in dictionary"
assert dengue["prevention"] == "mosquito repellent", "prevention should be 'mosquito repellent'"
assert len(dengue) == 5, "Dictionary should have 5 keys now"
print("✅ Exercise 2 Passed!")

# %% [markdown]
# ---
#
# ## Exercise 3: Access Values (20 points)
#
# Create a variable called `disease_symptoms` that contains the symptoms of dengue.
#
# Use the dictionary access syntax: `dictionary["key"]`

# %%
# Exercise 3: Access the symptoms value
# YOUR CODE HERE

disease_symptoms = None  # Replace None with your code

# Test your answer (don't modify this part)
print(f"Symptoms: {disease_symptoms}")

# %%
# Verification cell for Exercise 3
assert disease_symptoms == "high fever, headache", "disease_symptoms should be 'high fever, headache'"
print("✅ Exercise 3 Passed!")

# %% [markdown]
# ---
#
# ## Exercise 4: Create List of Dictionaries (20 points)
#
# Create a list called `diseases` containing 3 disease dictionaries.
#
# Each dictionary must have these keys: `name`, `symptoms`
#
# Use the following diseases:
# 1. Rubella - fever, rash
# 2. Cholera - severe diarrhea
# 3. GERD - heartburn

# %%
# Exercise 4: Create a list of 3 disease dictionaries
# YOUR CODE HERE

diseases = [
    # Add your 3 dictionaries here
]

# Test your answer (don't modify this part)
print(f"Number of diseases: {len(diseases)}")
for d in diseases:
    print(f"  - {d['name']}: {d['symptoms']}")

# %%
# Verification cell for Exercise 4
assert len(diseases) == 3, "List should contain exactly 3 diseases"
assert diseases[0]["name"] == "Rubella", "First disease should be 'Rubella'"
assert diseases[0]["symptoms"] == "fever, rash", "Rubella symptoms should be 'fever, rash'"
assert diseases[1]["name"] == "Cholera", "Second disease should be 'Cholera'"
assert diseases[1]["symptoms"] == "severe diarrhea", "Cholera symptoms should be 'severe diarrhea'"
assert diseases[2]["name"] == "GERD", "Third disease should be 'GERD'"
assert diseases[2]["symptoms"] == "heartburn", "GERD symptoms should be 'heartburn'"
print("✅ Exercise 4 Passed!")

# %% [markdown]
# ---
#
# ## Exercise 5: Loop Through Data (20 points)
#
# Create a list called `disease_names` that contains **only the names** of all diseases from the `diseases` list.
#
# Use a for loop to extract the names.
#
# Expected result: `['Rubella', 'Cholera', 'GERD']`

# %%
# Exercise 5: Extract all disease names using a loop
# YOUR CODE HERE

disease_names = []  # Start with empty list

# Add your for loop here


# Test your answer (don't modify this part)
print(f"Disease names: {disease_names}")

# %%
# Verification cell for Exercise 5
assert disease_names == ["Rubella", "Cholera", "GERD"], "disease_names should be ['Rubella', 'Cholera', 'GERD']"
print("✅ Exercise 5 Passed!")

# %% [markdown]
# ---
#
# ## 🎉 Congratulations!
#
# You have completed all exercises!
#
# ### Next Steps:
#
# 1. **Save this notebook** (Ctrl+S or Cmd+S)
#
# 2. **Push to GitHub:**
# ```bash
# git add .
# git commit -m "Complete Lab 01 exercises"
# git push
# ```
#
# 3. **Check your score** in the GitHub Actions tab
#
# ---
#
# ### Summary of What You Learned:
#
# | Exercise | Skill |
# |----------|-------|
# | 1 | Create a dictionary with key-value pairs |
# | 2 | Add new keys to an existing dictionary |
# | 3 | Access values using keys |
# | 4 | Create a list of dictionaries |
# | 5 | Loop through data and extract values |
#
# These skills are fundamental for working with RAG systems!
